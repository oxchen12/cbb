# %% [markdown]
# # WebScraper
#
# ## DISCLAIMER
#
# This file is deprecated. Its use case is now located in `util.py`.

# %%
import requests
import re
import typing
import datetime
from bs4 import BeautifulSoup
from dataclasses import dataclass
from enum import Enum, auto

# %%
HOME = "https://www.cbssports.com/college-basketball/gametracker"

@dataclass
class Team:
    name: str

class Page:
    def __init__(self, url: str):
        self._url: str = url
        self._page = None
        self._soup = None

    @property
    def page(self):
        if self._page is None:
            self._page = requests.get(self._url)
        return self._page
    
    @property
    def soup(self):
        if self._soup is None:
            self._soup = BeautifulSoup(self.page.content, "html.parser")
        return self._soup

class GamePage(Page):
    """
    Wrapper for a page describing a past game played.
    """
    class Category(Enum):
        RECAP = auto()
        BOX = auto()
        PLAYS = auto()

    def __init__(self, gid: str):
        assert(re.match(r"NCAAB_\d{8}_[A-Z]+@[A-Z]+", gid))
        self._gid: str = gid
        self._box = None
        self._plays = None
        self._home = None
        self._away = None
        Page.__init__(self, f"{HOME}/recap/{self._gid}/")

    def __repr__(self):
        return f"GamePage(gid={self._gid})"
    
    def _get_url(self, category: Category = Category.PLAYS):
        dest = None
        match category:
            case GamePage.Category.RECAP:
                dest = "recap"
            case GamePage.Category.BOX:
                dest = "boxscore"
            case GamePage.Category.PLAYS:
                dest = "playbyplay"
        if dest is not None:
            return f"{HOME}/{dest}/{self._gid}"
        return None
    
    def _get_soup(self, category: Category = Category.PLAYS):
        url = self._get_url(category=category)
        if url is not None:
            return BeautifulSoup(requests.get(url).content, "html.parser")
    
    @property
    def box_score(self):
        if self._box is None:
            self._box = self._get_soup(category=GamePage.Category.BOX)
        return self._box

    @property
    def plays(self):
        if self._plays is None:
            self._plays = self._get_soup(category=GamePage.Category.PLAYS)
        return self._plays
    
    @property
    def home(self):
        if self._home is None:
            self._home = re.match(r"NCAAB_\d+_[A-Z]+@([A-Z]+)", self._gid).group(1)
        return self._home
    
    @property
    def away(self):
        if self._away is None:
            self._away = re.match(r"NCAAB_\d+_([A-Z]+)@[A-Z]+", self._gid).group(1)
        return self._away

"""TODO: date, venue"""
class Game:
    PLAY_REGEX = r"\s*(\d+:\d+)\s+(?:\+(\d))?\s+((?:[A-Za-z0-9.'()]+ ?)+)\s+(\d+-\d+)?\s*"

    class Play:
        def __init__(self, raw: list):
            self.team, self.time, self.pts, self.desc, self.score = raw
        
        def __repr__(self):
            return f"Play(team={self.team}, time={self.time}, score={self.score})"

    def __init__(self, gid: str):
        assert(re.match(r"NCAAB_\d{8}_[A-Z]+@[A-Z]+", gid))
        self._gid = gid
        self._page = GamePage(gid)
        self._plays = None

    def __repr__(self):
        return f"Game(gid={self._gid})"

    @property
    def plays(self):
        if self._plays is None:
            self._plays = self._parse_plays()
        return self._plays
    
    @property
    def home(self):
        return self._page.home
    
    @property
    def away(self):
        return self._page.away
    
    @property
    def date(self):
        _, year, month, day = re.match(r".*(\d{4})(\d{2})(\d{2})", self.gid).groups()
        return datetime.date(year, month, day)

    @property
    def gid(self):
        return self._gid

    def _parse_plays(self):
        first, second = self._page.plays.find_all('div', {'class' : 'TableBase'})
        plays = [[], []]
        last_score = "0-0"
        for x in first.find_all('tr'):
            home = self.home in str(x)
            m = re.match(Game.PLAY_REGEX, x.text)
            if m:
                play = Game.Play([self.home if home else self.away] + list(m.groups()))
                play.pts = play.pts if play.pts is not None else 0
                if play.score is None:
                    play.score = last_score
                else:
                    last_score = play.score
                plays[0].append(play)
        for x in second.find_all('tr'):
            home = self.home in str(x)
            m = re.match(Game.PLAY_REGEX, x.text)
            if m:
                play = Game.Play([self.home if home else self.away] + list(m.groups()))
                play.pts = play.pts if play.pts is not None else 0
                if play.score is None:
                    play.score = last_score
                else:
                    last_score = play.score
                plays[1].append(play)
        return plays

# %%
unc = Page(f"https://www.cbssports.com/college-basketball/teams/UNC/north-carolina-tar-heels/schedule/")
soup = unc.soup

# %%
games = []

for x in soup.find_all('div', {'class' : "CellGame"}):
    for y in x.find_all('a'):
        game_ref_match = re.match(r"/college-basketball/gametracker/recap/(.+)/", y['href'])
        if game_ref_match is not None:
            games.append(Game(game_ref_match.group(1)))

# %%
games[0].plays
# Out:
# [[Play(team=UNC, time=20:00, score=0-0),
#   Play(team=UNC, time=19:48, score=0-2),
#   Play(team=RADFRD, time=19:36, score=3-2),
#   Play(team=UNC, time=19:23, score=3-5),
#   Play(team=RADFRD, time=19:05, score=3-5),
#   Play(team=RADFRD, time=19:03, score=3-5),
#   Play(team=RADFRD, time=18:54, score=6-5),
#   Play(team=UNC, time=18:47, score=6-8),
#   Play(team=RADFRD, time=18:16, score=6-8),
#   Play(team=RADFRD, time=17:58, score=6-8),
#   Play(team=UNC, time=17:53, score=6-8),
#   Play(team=UNC, time=17:51, score=6-8),
#   Play(team=UNC, time=17:47, score=6-8),
#   Play(team=UNC, time=17:45, score=6-8),
#   Play(team=UNC, time=17:44, score=6-10),
#   Play(team=RADFRD, time=17:26, score=8-10),
#   Play(team=UNC, time=17:13, score=8-13),
#   Play(team=RADFRD, time=16:50, score=8-13),
#   Play(team=UNC, time=16:48, score=8-13),
#   Play(team=UNC, time=16:40, score=8-15),
#   Play(team=RADFRD, time=16:22, score=10-15),
#   Play(team=UNC, time=15:58, score=10-17),
#   Play(team=RADFRD, time=15:58, score=10-17),
#   Play(team=UNC, time=15:58, score=10-17),
#   Play(team=UNC, time=15:58, score=10-17),
#   Play(team=RADFRD, time=15:58, score=10-17),
#   Play(team=RADFRD, time=15:43, score=10-17),
#   Play(team=UNC, time=15:41, score=10-17),
#   Play(team=UNC, time=15:23, score=10-17),
#   Play(team=RADFRD, time=14:55, score=10-17),
#   Play(team=UNC, time=14:45, score=10-17),
#   Play(team=UNC, time=14:45, score=10-17),
#   Play(team=UNC, time=14:33, score=10-17),
#   Play(team=RADFRD, time=14:11, score=10-17),
#   Play(team=UNC, time=14:09, score=10-17),
#   Play(team=UNC, time=14:07, score=10-17),
#   Play(team=RADFRD, time=13:52, score=12-17),
#   Play(team=UNC, time=13:39, score=12-20),
#   Play(team=RADFRD, time=13:13, score=14-20),
#   Play(team=UNC, time=13:09, score=14-20),
#   Play(team=RADFRD, time=12:51, score=16-20),
#   Play(team=RADFRD, time=12:40, score=16-20),
#   Play(team=UNC, time=12:34, score=16-20),
#   Play(team=RADFRD, time=12:32, score=16-20),
#   Play(team=UNC, time=12:18, score=16-20),
#   Play(team=RADFRD, time=12:02, score=18-20),
#   Play(team=UNC, time=11:55, score=18-20),
#   Play(team=RADFRD, time=11:48, score=18-20),
#   Play(team=UNC, time=11:46, score=18-20),
#   Play(team=UNC, time=11:39, score=18-20),
#   Play(team=RADFRD, time=11:37, score=18-20),
#   Play(team=RADFRD, time=11:15, score=18-20),
#   Play(team=UNC, time=11:13, score=18-20),
#   Play(team=UNC, time=11:11, score=18-20),
#   Play(team=RADFRD, time=11:01, score=18-20),
#   Play(team=RADFRD, time=10:59, score=18-20),
#   Play(team=RADFRD, time=10:56, score=20-20),
#   Play(team=UNC, time=10:34, score=20-23),
#   Play(team=RADFRD, time=10:04, score=22-23),
#   Play(team=UNC, time=9:39, score=22-25),
#   Play(team=RADFRD, time=9:39, score=22-25),
#   Play(team=UNC, time=9:39, score=22-25),
#   Play(team=UNC, time=9:39, score=22-26),
#   Play(team=RADFRD, time=9:10, score=22-26),
#   Play(team=RADFRD, time=9:08, score=22-26),
#   Play(team=RADFRD, time=9:08, score=22-26),
#   Play(team=UNC, time=8:49, score=22-26),
#   Play(team=RADFRD, time=8:47, score=22-26),
#   Play(team=RADFRD, time=8:36, score=24-26),
#   Play(team=UNC, time=8:25, score=24-26),
#   Play(team=RADFRD, time=8:23, score=24-26),
#   Play(team=RADFRD, time=8:14, score=27-26),
#   Play(team=UNC, time=8:02, score=27-26),
#   Play(team=RADFRD, time=7:53, score=29-26),
#   Play(team=RADFRD, time=7:43, score=29-26),
#   Play(team=UNC, time=7:43, score=29-26),
#   Play(team=UNC, time=7:42, score=29-26),
#   Play(team=UNC, time=7:40, score=29-26),
#   Play(team=UNC, time=7:38, score=29-28),
#   Play(team=RADFRD, time=7:15, score=31-28),
#   Play(team=RADFRD, time=7:15, score=31-28),
#   Play(team=UNC, time=6:48, score=31-28),
#   Play(team=RADFRD, time=6:46, score=31-28),
#   Play(team=RADFRD, time=6:44, score=31-28),
#   Play(team=RADFRD, time=6:43, score=31-28),
#   Play(team=UNC, time=6:41, score=31-28),
#   Play(team=UNC, time=6:29, score=31-30),
#   Play(team=RADFRD, time=6:00, score=31-30),
#   Play(team=RADFRD, time=5:58, score=31-30),
#   Play(team=RADFRD, time=5:54, score=31-30),
#   Play(team=RADFRD, time=5:52, score=31-30),
#   Play(team=RADFRD, time=5:52, score=31-30),
#   Play(team=UNC, time=5:41, score=31-30),
#   Play(team=RADFRD, time=5:39, score=31-30),
#   Play(team=UNC, time=5:34, score=31-30),
#   Play(team=RADFRD, time=5:18, score=31-30),
#   Play(team=RADFRD, time=5:10, score=31-30),
#   Play(team=UNC, time=5:10, score=31-31),
#   Play(team=UNC, time=5:10, score=31-32),
#   Play(team=UNC, time=4:43, score=31-32),
#   Play(team=RADFRD, time=4:43, score=32-32),
#   Play(team=RADFRD, time=4:43, score=33-32),
#   Play(team=UNC, time=4:33, score=33-32),
#   Play(team=RADFRD, time=4:31, score=33-32),
#   Play(team=UNC, time=4:17, score=33-32),
#   Play(team=RADFRD, time=4:17, score=34-32),
#   Play(team=RADFRD, time=4:17, score=35-32),
#   Play(team=UNC, time=3:52, score=35-34),
#   Play(team=RADFRD, time=3:40, score=35-34),
#   Play(team=RADFRD, time=3:40, score=35-34),
#   Play(team=UNC, time=3:40, score=35-34),
#   Play(team=UNC, time=3:28, score=35-34),
#   Play(team=RADFRD, time=3:26, score=35-34),
#   Play(team=RADFRD, time=3:16, score=37-34),
#   Play(team=RADFRD, time=3:05, score=37-34),
#   Play(team=UNC, time=3:05, score=37-35),
#   Play(team=UNC, time=3:05, score=37-36),
#   Play(team=RADFRD, time=2:51, score=37-36),
#   Play(team=RADFRD, time=2:49, score=37-36),
#   Play(team=RADFRD, time=2:47, score=39-36),
#   Play(team=UNC, time=2:34, score=39-38),
#   Play(team=RADFRD, time=2:13, score=41-38),
#   Play(team=UNC, time=1:58, score=41-38),
#   Play(team=RADFRD, time=1:56, score=41-38),
#   Play(team=RADFRD, time=1:50, score=41-38),
#   Play(team=UNC, time=1:48, score=41-38),
#   Play(team=UNC, time=1:40, score=41-38),
#   Play(team=UNC, time=1:38, score=41-38),
#   Play(team=RADFRD, time=1:35, score=41-38),
#   Play(team=UNC, time=1:35, score=41-39),
#   Play(team=UNC, time=1:35, score=41-40),
#   Play(team=RADFRD, time=1:20, score=41-40),
#   Play(team=UNC, time=1:18, score=41-40),
#   Play(team=UNC, time=1:13, score=41-40),
#   Play(team=RADFRD, time=1:11, score=41-40),
#   Play(team=RADFRD, time=1:04, score=41-40),
#   Play(team=UNC, time=1:02, score=41-40),
#   Play(team=RADFRD, time=0:55, score=41-40),
#   Play(team=UNC, time=0:55, score=41-41),
#   Play(team=UNC, time=0:55, score=41-42),
#   Play(team=RADFRD, time=0:47, score=41-42),
#   Play(team=UNC, time=0:40, score=41-44),
#   Play(team=RADFRD, time=0:40, score=41-44),
#   Play(team=RADFRD, time=0:40, score=41-44),
#   Play(team=UNC, time=0:40, score=41-44),
#   Play(team=RADFRD, time=0:40, score=41-44),
#   Play(team=RADFRD, time=0:37, score=41-44),
#   Play(team=UNC, time=0:35, score=41-44),
#   Play(team=UNC, time=0:28, score=41-44),
#   Play(team=UNC, time=0:06, score=41-46),
#   Play(team=UNC, time=0:00, score=41-46)],
#  [Play(team=RADFRD, time=19:47, score=43-46),
#   Play(team=UNC, time=19:47, score=43-46),
#   Play(team=RADFRD, time=19:47, score=44-46),
#   Play(team=UNC, time=19:36, score=44-49),
#   Play(team=RADFRD, time=19:09, score=46-49),
#   Play(team=UNC, time=18:54, score=46-49),
#   Play(team=UNC, time=18:52, score=46-49),
#   Play(team=UNC, time=18:47, score=46-49),
#   Play(team=UNC, time=18:45, score=46-49),
#   Play(team=UNC, time=18:38, score=46-49),
#   Play(team=RADFRD, time=18:36, score=46-49),
#   Play(team=RADFRD, time=18:27, score=46-49),
#   Play(team=UNC, time=18:25, score=46-49),
#   Play(team=UNC, time=18:12, score=46-51),
#   Play(team=RADFRD, time=17:54, score=48-51),
#   Play(team=RADFRD, time=17:36, score=48-51),
#   Play(team=UNC, time=17:36, score=48-52),
#   Play(team=UNC, time=17:36, score=48-52),
#   Play(team=RADFRD, time=17:36, score=48-52),
#   Play(team=RADFRD, time=17:19, score=50-52),
#   Play(team=UNC, time=17:12, score=50-52),
#   Play(team=RADFRD, time=17:06, score=50-52),
#   Play(team=RADFRD, time=17:04, score=50-52),
#   Play(team=RADFRD, time=16:49, score=50-52),
#   Play(team=UNC, time=16:47, score=50-52),
#   Play(team=UNC, time=16:40, score=50-54),
#   Play(team=RADFRD, time=16:14, score=50-54),
#   Play(team=UNC, time=16:12, score=50-54),
#   Play(team=UNC, time=16:00, score=50-54),
#   Play(team=UNC, time=15:45, score=50-56),
#   Play(team=RADFRD, time=15:30, score=52-56),
#   Play(team=UNC, time=15:18, score=52-56),
#   Play(team=RADFRD, time=15:16, score=52-56),
#   Play(team=RADFRD, time=14:56, score=54-56),
#   Play(team=UNC, time=14:56, score=54-56),
#   Play(team=RADFRD, time=14:56, score=55-56),
#   Play(team=UNC, time=14:45, score=55-58),
#   Play(team=RADFRD, time=14:29, score=55-58),
#   Play(team=UNC, time=14:27, score=55-58),
#   Play(team=RADFRD, time=14:14, score=55-58),
#   Play(team=UNC, time=14:11, score=55-58),
#   Play(team=RADFRD, time=14:09, score=55-58),
#   Play(team=RADFRD, time=13:43, score=55-58),
#   Play(team=UNC, time=13:41, score=55-58),
#   Play(team=RADFRD, time=13:35, score=55-58),
#   Play(team=UNC, time=13:35, score=55-58),
#   Play(team=UNC, time=13:35, score=55-59),
#   Play(team=RADFRD, time=13:10, score=55-59),
#   Play(team=UNC, time=13:08, score=55-59),
#   Play(team=UNC, time=13:01, score=55-61),
#   Play(team=UNC, time=12:43, score=55-61),
#   Play(team=RADFRD, time=12:31, score=55-61),
#   Play(team=UNC, time=12:29, score=55-61),
#   Play(team=UNC, time=12:21, score=55-63),
#   Play(team=RADFRD, time=12:21, score=55-63),
#   Play(team=UNC, time=12:21, score=55-63),
#   Play(team=RADFRD, time=12:21, score=55-63),
#   Play(team=RADFRD, time=11:51, score=58-63),
#   Play(team=UNC, time=11:39, score=58-63),
#   Play(team=RADFRD, time=11:37, score=58-63),
#   Play(team=RADFRD, time=11:21, score=58-63),
#   Play(team=UNC, time=11:19, score=58-63),
#   Play(team=UNC, time=11:08, score=58-63),
#   Play(team=RADFRD, time=10:56, score=58-63),
#   Play(team=UNC, time=10:56, score=58-63),
#   Play(team=UNC, time=10:39, score=58-65),
#   Play(team=RADFRD, time=10:26, score=58-65),
#   Play(team=UNC, time=10:25, score=58-65),
#   Play(team=UNC, time=10:23, score=58-65),
#   Play(team=UNC, time=10:15, score=58-65),
#   Play(team=UNC, time=10:13, score=58-65),
#   Play(team=RADFRD, time=10:07, score=58-65),
#   Play(team=UNC, time=10:07, score=58-66),
#   Play(team=UNC, time=10:07, score=58-67),
#   Play(team=RADFRD, time=9:43, score=58-67),
#   Play(team=UNC, time=9:41, score=58-67),
#   Play(team=UNC, time=9:33, score=58-67),
#   Play(team=RADFRD, time=9:31, score=58-67),
#   Play(team=UNC, time=9:10, score=58-67),
#   Play(team=RADFRD, time=9:10, score=59-67),
#   Play(team=RADFRD, time=9:10, score=60-67),
#   Play(team=UNC, time=8:53, score=60-69),
#   Play(team=UNC, time=8:39, score=60-69),
#   Play(team=RADFRD, time=8:39, score=60-69),
#   Play(team=RADFRD, time=8:39, score=61-69),
#   Play(team=UNC, time=8:27, score=61-69),
#   Play(team=RADFRD, time=8:25, score=61-69),
#   Play(team=RADFRD, time=8:19, score=61-69),
#   Play(team=RADFRD, time=8:17, score=61-69),
#   Play(team=RADFRD, time=8:14, score=61-69),
#   Play(team=UNC, time=8:12, score=61-69),
#   Play(team=UNC, time=7:56, score=61-71),
#   Play(team=RADFRD, time=7:26, score=61-71),
#   Play(team=UNC, time=7:24, score=61-71),
#   Play(team=UNC, time=7:10, score=61-74),
#   Play(team=RADFRD, time=7:06, score=61-74),
#   Play(team=UNC, time=7:06, score=61-74),
#   Play(team=RADFRD, time=6:49, score=61-74),
#   Play(team=RADFRD, time=6:49, score=61-74),
#   Play(team=UNC, time=6:49, score=61-74),
#   Play(team=UNC, time=6:39, score=61-76),
#   Play(team=RADFRD, time=6:26, score=61-76),
#   Play(team=RADFRD, time=6:24, score=61-76),
#   Play(team=RADFRD, time=6:19, score=63-76),
#   Play(team=RADFRD, time=6:01, score=63-76),
#   Play(team=UNC, time=6:01, score=63-77),
#   Play(team=UNC, time=6:01, score=63-77),
#   Play(team=UNC, time=6:01, score=63-77),
#   Play(team=UNC, time=6:00, score=63-77),
#   Play(team=UNC, time=5:53, score=63-77),
#   Play(team=UNC, time=5:51, score=63-77),
#   Play(team=UNC, time=5:46, score=63-79),
#   Play(team=RADFRD, time=5:35, score=63-79),
#   Play(team=UNC, time=5:29, score=63-79),
#   Play(team=RADFRD, time=5:18, score=63-79),
#   Play(team=RADFRD, time=5:16, score=63-79),
#   Play(team=RADFRD, time=5:11, score=66-79),
#   Play(team=RADFRD, time=4:59, score=66-79),
#   Play(team=UNC, time=4:59, score=66-79),
#   Play(team=UNC, time=4:59, score=66-79),
#   Play(team=UNC, time=4:49, score=66-81),
#   Play(team=RADFRD, time=4:21, score=66-81),
#   Play(team=RADFRD, time=4:19, score=66-81),
#   Play(team=RADFRD, time=4:16, score=68-81),
#   Play(team=UNC, time=4:04, score=68-81),
#   Play(team=UNC, time=4:02, score=68-81),
#   Play(team=UNC, time=3:57, score=68-83),
#   Play(team=RADFRD, time=3:42, score=68-83),
#   Play(team=RADFRD, time=3:40, score=68-83),
#   Play(team=RADFRD, time=3:33, score=68-83),
#   Play(team=UNC, time=3:31, score=68-83),
#   Play(team=UNC, time=3:19, score=68-83),
#   Play(team=RADFRD, time=3:17, score=68-83),
#   Play(team=RADFRD, time=3:04, score=68-83),
#   Play(team=UNC, time=3:04, score=68-83),
#   Play(team=UNC, time=2:42, score=68-85),
#   Play(team=RADFRD, time=2:21, score=70-85),
#   Play(team=UNC, time=2:11, score=70-85),
#   Play(team=UNC, time=1:50, score=70-85),
#   Play(team=UNC, time=1:48, score=70-85),
#   Play(team=UNC, time=1:44, score=70-85),
#   Play(team=RADFRD, time=1:42, score=70-85),
#   Play(team=RADFRD, time=1:32, score=70-85),
#   Play(team=UNC, time=1:30, score=70-85),
#   Play(team=UNC, time=1:08, score=70-85),
#   Play(team=RADFRD, time=1:06, score=70-85),
#   Play(team=RADFRD, time=0:59, score=70-85),
#   Play(team=RADFRD, time=0:44, score=70-85),
#   Play(team=UNC, time=0:42, score=70-85),
#   Play(team=RADFRD, time=0:23, score=70-85),
#   Play(team=UNC, time=0:23, score=70-86),
#   Play(team=UNC, time=0:23, score=70-86),
#   Play(team=RADFRD, time=0:23, score=70-86),
#   Play(team=RADFRD, time=0:13, score=70-86),
#   Play(team=UNC, time=0:11, score=70-86),
#   Play(team=UNC, time=0:00, score=70-86)]]
